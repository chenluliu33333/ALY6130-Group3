# %% [markdown]
# # Exploratory Data Analysis
#
# Loads processed risk datasets and checks basic distributions used in the assessment.

# %%
import pandas as pd
from pathlib import Path

processed = Path('../data/processed')
quant = pd.read_csv(processed / 'quantitative_risk_summary.csv')
ml = pd.read_csv(processed / 'synthetic_ml_dataset.csv')

print('Quantitative risk summary:')
display(quant.head(10))
print('Synthetic ML dataset shape:', ml.shape)
display(ml.describe().T.head(15))
