# %% [markdown]
# # Monte Carlo Simulation
#
# Reviews the Monte Carlo summary and tail-risk contribution outputs.

# %%
import pandas as pd
from pathlib import Path

summary = pd.read_csv(Path('../data/processed/monte_carlo_summary.csv'))
tail = pd.read_csv(Path('../data/processed/tail_contribution.csv'))
print('Monte Carlo summary:')
display(summary)
print('Tail risk contribution:')
display(tail)
